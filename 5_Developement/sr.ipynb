# %%
import pandas as pd

data = pd.read_csv('c.csv', encoding = 'euc-kr',header=None, engine='python')
df = data.iloc[:,1:]
c = ['time','contents']
df.columns = c

df['start_time'] = pd.to_datetime(df.time, format='%M:%S.%f')
df["end_time"] = df.start_time.shift(-1)
df["end_time"].iloc[-1] = df.start_time.iloc[-1]+ datetime.timedelta(seconds=3)
df['start_time'] = pd.to_datetime(df['start_time']).dt.strftime("%H:%M:%S.%f").str[:-3]
df['end_time'] = pd.to_datetime(df['end_time']).dt.strftime("%H:%M:%S.%f").str[:-3]
df["seq_num"] = df.index.astype(int) + 1
df.seq_num = df.seq_num.astype('str')

df['srt_time'] = df['start_time'].str[:8] + "," +  df['start_time'].str[9:]+ " --> "
df['srt_time'] = df['srt_time'] + df['end_time'].str[:8] + "," + df['end_time'].str[9:]

df['srt'] = df['seq_num'].str[:] + "\n" \
                    + df['srt_time'].str[:] + "\n" \
                    + df['contents'] \
                    + "\n\n"

df.head()
# Out:
# C:\Users\masta\AppData\Local\Temp\ipykernel_2528\2741424628.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["end_time"].iloc[-1] = df.start_time.iloc[-1]+ datetime.timedelta(seconds=3)
#       time                                contents    start_time  \
# 0  00:04.0             인도네시아의 수도 자카르타는 자바의 북서쪽 해안,  00:00:04.000
# 1  00:09.0                       세계에서 가장 인구가 많은 섬.  00:00:09.000
# 2  00:12.0  인도네시아의 정치 및 경제 성장동력의 역할을 하는 이 거대한 도시에는  00:00:12.000
# 3  00:17.0             1,000 만 명이 넘는 사람들이 살고 있습니다.  00:00:17.000
# 4  00:26.0               자카르타의 엄청난 크기와 열광적인 속도가 나는  00:00:26.000
#
#        end_time seq_num                       srt_time  \
# 0  00:00:09.000       1  00:00:04,000 --> 00:00:09,000
# 1  00:00:12.000       2  00:00:09,000 --> 00:00:12,000
# ...

# %%
srt = df.srt.copy()

# %%
srt.to_csv('subtitle.srt', header=None, index=False,)

# %%
srt.values
# Out:
# array(['1\n00:00:04,000 --> 00:00:09,000\n인도네시아의 수도 자카르타는 자바의 북서쪽 해안,\n\n',
#        '2\n00:00:09,000 --> 00:00:12,000\n세계에서 가장 인구가 많은 섬.\n\n',
#        '3\n00:00:12,000 --> 00:00:17,000\n이 거대한 대도시는 공화국의 정치 및 경제 엔진 룸,\n\n',
#        '4\n00:00:17,000 --> 00:00:26,000\n1,000 만 명이 넘는 사람들이 살고 있습니다.\n\n',
#        '5\n00:00:26,000 --> 00:00:29,000\n자카르타의 엄청난 크기와 열광적인 속도\n\n',
#        '6\n00:00:29,000 --> 00:00:33,000\n때로는 도시처럼 느껴질 수 있습니다. 이음새에서 풀기.\n\n',
#        '7\n00:00:33,000 --> 00:00:39,000\n그러나 그 천만 명의 주민들은 모든 것을 함께 유지하십시오.\n\n',
#        '8\n00:00:39,000 --> 00:00:42,000\n교통 체증이 잊혀진 지 오래,\n\n',
#        '9\n00:00:42,000 --> 00:00:50,000\n그것은 따뜻함, 자부심, 미소입니다. 기억되는 사람들.\n\n',
#        '10\n00:00:50,000 --> 00:00:52,000\n다소 껄끄러운 평판에도 불구하고,\n\n',
#        '11\n00:00:52,000 --> 00:01:01,000\n이것은 종종 매력이있는 도시입니다. 여행자의 마음.\n\n',
#        '12\n00:01:01,000 --> 00:01:05,000\n자카르타의 심장부에서 이 나라의 진정한 모습을 보고 싶으시다면\n\n',
#        '13\n00:01:05,000 --> 00:01:08,000\n메르데카 광장으로 가보세요.\n\n',
# ...
