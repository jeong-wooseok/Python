# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup as bs
import time

url ='https://tradingeconomics.com/'
html = requests.get(url).text
soup = bs(html,'html.parser')
head = soup.find('div', {"class": "col-md-7"}).text.split('\r\n                    ')[1].split('\r\n                  \n')
articles = soup.find_all('div', {"class": "home-tile-inside"})
news = [a.text.split('\n') for a in  articles]

t = []
c = []
news_d=dict()

t.append(head[0])
c.append(head[1])

for i  in news:
    for idx, j in enumerate(i):
        if idx%len(i) == 1: t.append(j)
        elif idx%len(i) == 2: c.append(j)
            
file = time.strftime('%Y_%m_%d', time.localtime(time.time()))
news_d['title'] = t   
news_d['contents'] = c 
news_df = pd.DataFrame(news_d)
news_df.to_csv(f'{file}.csv')
news_df
# Out:
#                                              title  \
# 0                                       Week Ahead
# 1                         WTI Crude Oil Falls 2.9%
# 2                     Dollar Surges to 4-Week High
# 3              TSX Closes Lower, Sheds Weekly 0.7%
# 4       US Stocks Extend Decline, Book Weekly Loss
# 5    US Retail Sales Unexpectedly Drop in December
# 6  European Stocks Fall the Most in Almost 4 Weeks
# 7       US Consumer Morale Deteriorates in January
# 8           UK GDP Growth Slows Sharply in Sep-Nov
# 9       Gold Falls for 2nd Week on Stronger Dollar
#
#                                             contents
# 0  The fourth-quarter earnings season continues n...
# 1  WTI crude oil prices dropped 2.9% on Friday to...
# 2  The dollar index jumped around 0.7% to 90.78 o...
# 3  Canada’s TSX lost 42 points or 0.2% to 17,916 ...
# 4  Wall Street closed in the red for the second s...
# 5  US retail trade fell 0.7 percent from a month ...
# 6  European stocks suffered their worst session s...
# 7  The University of Michigan's consumer sentimen...
# 8  Britain's GDP grew by 4.1 percent in the three...
# 9  Gold sank around 1% to $1825 an ounce on Frida...
