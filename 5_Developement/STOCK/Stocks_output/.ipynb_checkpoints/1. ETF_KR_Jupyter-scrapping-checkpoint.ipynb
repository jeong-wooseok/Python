# %% [markdown]
# ### 기본설정

# %% [markdown]
# #### 크롬드라이버 설치

# %% [markdown]
#  <br>
# 크롬 버전에 맞춰서 웹브라우저를 다운 받아야 합니다.
#
# 크롬 버전 확인하는 방법입니다.
# 크롬을 열어준후 설정에서 설치된 크롬의 버전의 확인합니다.
#
# ![크롬버전 확인하기1](https://github.com/jeong-wooseok/Python/blob/master/refer/img/img_20201227_5.png?raw=true)
#
# ![크롬버전 확인하기2](https://github.com/jeong-wooseok/Python/blob/master/refer/img/img_20201227_6.png?raw=true)
#
# [크롬드라이버다운로드 바로가기](https://chromedriver.chromium.org/downloads)
# <br>
# 소수점 앞의 두자리가 동일한 것으로 다운로드 합니다.
#
# ![크롬버전 확인하기2](https://github.com/jeong-wooseok/Python/blob/master/refer/img/img_20201227_7.png?raw=true)
# 현재 파일 경로를 확인하고, 크롬 드라이버를 넣어줍니다.

# %% [markdown]
# #### 기타 기본설정

# %%
# colab에서 싷행할 경우
# !pip install -U selenium bs4 requests finance-datareader

# 파일 저장 폴더생성
import os
PROJECT_ROOT_DIR = "./fdr_output"
CHAPTER_ID = "stock_check"
SAMPLES_PATH = os.path.join(PROJECT_ROOT_DIR, "samples", CHAPTER_ID)
os.makedirs(SAMPLES_PATH, exist_ok=True)

#파일 경로 생성함수
def mkfile(file): 
    file = os.path.join(SAMPLES_PATH,f'{file}.xlsx')
    return file

sample_o = os.path.join(SAMPLES_PATH,'sample.xlsx')
test = os.path.join(SAMPLES_PATH,'test.xlsx')
sample_modi = os.path.join(SAMPLES_PATH,'sample_modi.xlsx')
sample_modi1 = os.path.join(SAMPLES_PATH,'sample_modi1.xlsx')

# 결측치제거 및 scaling
def scale(df):
    from sklearn.preprocessing import MinMaxScaler
    import pandas as pd
    df = df.fillna(method='pad').dropna(axis=0)
    scaler = MinMaxScaler()
    scaler.fit(df)
    output = scaler.transform(df)
    output = pd.DataFrame(output, columns=df.columns, index=df.index.values)
    return output
    
# 시각화
# %matplotlib inline
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm

mpl.rcParams['axes.unicode_minus'] = False
path = 'C:/Windows/Fonts/malgun.ttf'
font_name = fm.FontProperties(fname=path, size=50).get_name()
plt.rc('font', family=font_name)

plt.rcParams["axes.grid"] = True
plt.rcParams["figure.figsize"] = (12,6)
plt.rcParams['axes.unicode_minus'] = False
plt.rcParams["axes.formatter.limits"] = -10000, 10000
mpl.rc('axes', labelsize=14)
mpl.rc('xtick', labelsize=12)
mpl.rc('ytick', labelsize=12)

# 불필요한 경고 무시
import warnings
warnings.filterwarnings(action="ignore", message="^internal gelsd")

# %% [markdown]
# ### 크롤링을 통해 ETF 데이터 가져오기

# %% [markdown]
# 파이썬의 라이브러리인 셀레니움을 사용하여 크롤링을 진행합니다.
# 한국예탁결제원의 증권정보포탈 사이트를 참조합니다. <br>
# (한번 다운로드 받으면 저장되니, 자주 실행하지 마세요)

# %%
'''Terminal에서 라이브러리 설치하기:
pip install -U selenium bs4 pandas requests finance-datareader matplotlib '''
from selenium import webdriver
from bs4 import BeautifulSoup
import time
import pandas as pd
import os

try:
    # 홈페이지에 접근하여 ETF 항목 클릭
    driver=webdriver.Chrome("./chromedriver.exe")
    driver.get("http://seibro.or.kr/websquare/control.jsp?w2xPath=/IPORTAL/user/etf/BIP_CNTS06025V.xml&menuNo=174")
    time.sleep(5)
    a=driver.find_element_by_xpath('//*[@id="image10"]')
    a.click()
    path = 'ETF.txt'
    if os.path.exists(path):os.remove(path)

    # 페이지 넘김
    i=1
    while True: 
        time.sleep(1)
        a=driver.find_element_by_xpath('//*[@id="pageList1_page_%d"]'%i)
        a.click()

        time.sleep(2)
        html=driver.page_source
        soup=BeautifulSoup(html,"html.parser")

        f = open("ETF.txt", 'a')
        for anchors in soup.select("#grid1_body_tbody")[0]:
            for anchor in anchors.select("td"):
                data = anchor.get_text()+'\n'
                f.write(data)
        f.close()
        i+=1
# 더이상 읽을 페이지 없을 때, 
except:
     
    print('수집이 끝났습니다')
# Out:
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# <ipython-input-10-f40d2ef37f7b> in <module>
#      32         time.sleep(1)
# ---> 33         a=driver.find_element_by_xpath('//*[@id="pageList1_page_%d"]'%i)
#      34         a.click()
#
# C:\Dev\Miniconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element_by_xpath(self, xpath)
#     393         """
# --> 394         return self.find_element(by=By.XPATH, value=xpath)
#     395
#
# C:\Dev\Miniconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element(self, by, value)
#     975                 value = '[name="%s"]' % value
# --> 976         return self.execute(Command.FIND_ELEMENT, {
#     977             'using': by,
#
# C:\Dev\Miniconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     320         if response:
# --> 321             self.error_handler.check_response(response)
#     322             response['value'] = self._unwrap_value(
#
# C:\Dev\Miniconda3\lib\site-packages\selenium\webdriver\remote\errorhandler.py in check_response(self, response)
#     241             raise exception_class(message, screen, stacktrace, alert_text)
# --> 242         raise exception_class(message, screen, stacktrace)
#     243
#
# NoSuchElementException: Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="pageList1_page_17"]"}
#   (Session info: chrome=87.0.4280.141)
#
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# C:\Dev\Miniconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '총보수'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-10-f40d2ef37f7b> in <module>
#      77
#      78     # 보수, 수익율 없는 상품 제거하기
# ---> 79     df = df.drop(df[df['총보수']==''].index)
#      80     df = df.drop(df[df['수익율']==''].index)
#      81
#
# C:\Dev\Miniconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3022             if self.columns.nlevels > 1:
#    3023                 return self._getitem_multilevel(key)
# -> 3024             indexer = self.columns.get_loc(key)
#    3025             if is_integer(indexer):
#    3026                 indexer = [indexer]
#
# C:\Dev\Miniconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
# -> 3082                 raise KeyError(key) from err
#    3083
#    3084         if tolerance is not None:
#
# KeyError: '총보수'

# %%
# df 생성

import pandas as pd
etf = mkfile('etf') 

df = pd.DataFrame()
cols = ['종목명','코드','유형','순자산','종가','거래량','수익율','총보수','운용사']
lines = [1,2,3,4,5,6,9,15,16]
with open('ETF.txt','r') as f:
    data = f.readlines()
    
    for idx in range(len(cols)):
        df[cols[idx]] = [j.replace('\n','') for i, j in enumerate(data) if i % 17 == lines[idx]]
    
# 전처리 : 보수, 수익율 없는 상품 제거
df = df.drop(df[df['총보수']==''].index)
df = df.drop(df[df['수익율']==''].index)

# 전처리 : 계산 가능타입으로 변환
for j in cols[3:6]:
    df[j] = df[j].apply(lambda x: x.replace(',',''))
    df[j] = df[j].astype(int)
for j in cols[6:8]:
    df[j] = df[j].astype(float)

df.to_csv(etf,sep=',',encoding='euc-kr')

print(f'추출한 총 ETF의 수 {len(df)}개')
# Out:
# 추출한 총 ETF의 수 459개

# %%
df.유형.unique()
# Out:
# array(['시장지수/코스피200', '채권/단기자금', '시장지수/MSCI Korea Index', '파생상품/레버리지',
#        '그룹주/삼성', '파생상품/인버스', '채권/회사채권', '해외지수/해외지수', '테마/우량주', '테마/기타',
#        '시장지수/코스닥', '섹터/IT', '상품/원유', '스타일/스타일', '상품/금속', '채권/국공채권',
#        '섹터/금융', '섹터/경기소비재', '섹터/의료', '시장지수/KRX300', '테마/SRI', '통화/미국달러',
#        '기타/기타', '상품/농산물', '그룹주/현대차', '투자전략/투자전략', '섹터/산업재', '섹터/소재',
#        '파생상품/구조화', '시장지수/코스피50', '섹터/필수소비재', '시장지수/코스피100', '시장지수/KRX100',
#        '그룹주/LG', '그룹주/기타', '통화/기타통화', '섹터/통신서비스'], dtype=object)

# %% [markdown]
# #### ETF : 3개월 수익율 순위

# %%
df.sort_values('수익율',ascending =False)[:20]
# Out:
#                     종목명      코드           유형    순자산     종가       거래량     수익율  \
# 107     TIGER 200IT레버리지  243880    파생상품/레버리지    564  74660     24085  126.79
# 259  TIGER 200에너지화학레버리지  243890    파생상품/레버리지    133  24205     34820   97.11
# 155          TIGER 레버리지  123320    파생상품/레버리지    298  27000    782450   86.08
# 104    HANARO 200선물레버리지  304780    파생상품/레버리지    593  31175     13901   86.01
# 5            KODEX 레버리지  122630    파생상품/레버리지  17968  28660  61361853   85.92
# 262   ARIRANG 200선물레버리지  253150    파생상품/레버리지    129  51600      9814   85.91
# 160     KOSEF 200선물레버리지  253250    파생상품/레버리지    283  25640     26049   85.66
# 65      TIGER 200선물레버리지  267770    파생상품/레버리지   1247  21455   3100938   85.36
# 253         KINDEX 레버리지  152500    파생상품/레버리지    136  11260    112431   85.35
# 137    KBSTAR 200선물레버리지  252400    파생상품/레버리지    365  25980     69907   85.11
# 182    KODEX KRX300레버리지  306950    파생상품/레버리지    225  22505     11602   80.40
# 231   KBSTAR KRX300레버리지  307010    파생상품/레버리지    155  22185      1593   79.64
# 31    TIGER KRX2차전지K-뉴딜  364980        테마/기타   4232  17355    976809   60.47
# 21         KODEX 2차전지산업  305720        테마/기타   5244  19035   2350016   54.25
# 24         TIGER 200 IT  139260        섹터/IT   4808  40575    594074   51.71
# 237      KODEX 200IT TR  363580        섹터/IT    152  15155      3981   51.02
# 210        KBSTAR 200IT  285000        섹터/IT    178  18025      6361   50.65
# 127    TIGER 현대차그룹+펀더멘털  138540      그룹주/현대차    401  26705     70434   46.49
# 29         TIGER 2차전지테마  305540        테마/기타   4387  17100   1417286   45.04
# 461    ARIRANG KRX300IT  309170  시장지수/KRX300     29  20680      1337   44.87
#
#       총보수          운용사
# 107  0.69     미래에셋자산운용
# 259  0.69     미래에셋자산운용
# 155  0.09     미래에셋자산운용
# 104  0.45  엔에이치아문디자산운용
# 5    0.64       삼성자산운용
# 262  0.06       한화자산운용
# 160  0.46     키움투자자산운용
# 65   0.09     미래에셋자산운용
# 253  0.30     한국투자신탁운용
# 137  0.60      케이비자산운용
# 182  0.64       삼성자산운용
# 231  0.55      케이비자산운용
# 31   0.40     미래에셋자산운용
# 21   0.45       삼성자산운용
# 24   0.40     미래에셋자산운용
# 237  0.15       삼성자산운용
# 210  0.19      케이비자산운용
# 127  0.15     미래에셋자산운용
# 29   0.50     미래에셋자산운용
# 461  0.40       한화자산운용

# %% [markdown]
# #### 종목명, 유형 등 조회

# %%
df[df.종목명.str.contains('TIGER 구리')]
# Out:
#             종목명      코드     유형  순자산    종가   거래량    수익율   총보수       운용사
# 308  TIGER 구리실물  160580  상품/금속  100  8230  5535  14.15  0.85  미래에셋자산운용

# %%
#상품 종류만 추려서 보기
df[(df.유형.str.contains('상품')) & (~df.유형.str.contains('파생상품'))]
# Out:
#                         종목명      코드      유형   순자산     종가      거래량    수익율  \
# 30         KODEX WTI원유선물(H)  261220   상품/원유  4241   7690  2608820  23.73
# 40            KODEX 골드선물(H)  132030   상품/금속  2465  13090   331722   0.42
# 62             KODEX 은선물(H)  144600   상품/금속  1394   5635  1074015  12.03
# 73    TIGER 원유선물Enhanced(H)  130680   상품/원유  1097   2310  1349300  17.56
# 116  TIGER 농산물선물Enhanced(H)  137610  상품/농산물   466   5460    85337  17.93
# 200           TIGER 골드선물(H)  319640   상품/금속   195  13915    19632   0.32
# 228           KODEX 구리선물(H)  138910   상품/금속   158   6910    35933  21.87
# 245        KODEX 3대농산물선물(H)  271060  상품/농산물   141   9710    26411  20.02
# 308              TIGER 구리실물  160580   상품/금속   100   8230     5535  14.15
# 329            KODEX 콩선물(H)  138920  상품/농산물    90  11265    11858  27.72
# 347           TIGER 금은선물(H)  139320   상품/금속    83  10315    12942   1.43
# 414         KBSTAR 팔라듐선물(H)  334690   상품/금속    57  14175     4822   1.29
# 458           TIGER 금속선물(H)  139310   상품/금속    35   5860     3226  18.86
#
#       총보수       운용사
# 30   0.35    삼성자산운용
# 40   0.68    삼성자산운용
# 62   0.68    삼성자산운용
# 73   0.70  미래에셋자산운용
# 116  0.70  미래에셋자산운용
# 200  0.39  미래에셋자산운용
# 228  0.68    삼성자산운용
# 245  0.55    삼성자산운용
# 308  0.85  미래에셋자산운용
# 329  0.68    삼성자산운용
# 347  0.70  미래에셋자산운용
# 414  0.60   케이비자산운용
# 458  0.70  미래에셋자산운용

# %% [markdown]
# ### 파생상품 제외한 목록 만들기 (연금계좌 활용)

# %% [markdown]
# #### 연금용 ETF : 3개월 수익율 순위

# %%
a = '파생상품'
df1 = df[~df['유형'].str.contains(a)]
# print(df['유형'].unique())
# print()
# print(df1['유형'].unique())

# etf_연금 = mkfile('etf_연금') 
# df1.to_csv(etf_연금,sep=',',encoding='euc-kr')
df1.sort_values('수익율',ascending =False)[:20]
# Out:
#                           종목명      코드           유형    순자산     종가      거래량  \
# 31          TIGER KRX2차전지K-뉴딜  364980        테마/기타   4232  17355   976809
# 21               KODEX 2차전지산업  305720        테마/기타   5244  19035  2350016
# 24               TIGER 200 IT  139260        섹터/IT   4808  40575   594074
# 237            KODEX 200IT TR  363580        섹터/IT    152  15155     3981
# 210              KBSTAR 200IT  285000        섹터/IT    178  18025     6361
# 127          TIGER 현대차그룹+펀더멘털  138540      그룹주/현대차    401  26705    70434
# 29               TIGER 2차전지테마  305540        테마/기타   4387  17100  1417286
# 461          ARIRANG KRX300IT  309170  시장지수/KRX300     29  20680     1337
# 130                  KODEX IT  266370        섹터/IT    380  22335    40864
# 58                  KODEX 자동차  091180     섹터/경기소비재   1539  23500   373100
# 327              KBSTAR 5대그룹주  105780       그룹주/기타     90   8995     8394
# 334               TIGER 베타플러스  170350    투자전략/투자전략     88  19985      439
# 70           KBSTAR 대형고배당10TR  315960      스타일/스타일   1148  17175    23814
# 20                TIGER TOP10  292150       테마/우량주   5634  15550   809718
# 96   KBSTAR 미국S&P원유생산기업(합성 H)  219390    해외지수/해외지수    661   2915   634528
# 435           KBSTAR 200에너지화학  284990        섹터/소재     48  14180     3659
# 225            TIGER 삼성그룹펀더멘털  138520       그룹주/삼성    159  13450    13056
# 66            KINDEX 삼성그룹섹터가중  108450       그룹주/삼성   1241  17475    28142
# 6                  KODEX 삼성그룹  102780       그룹주/삼성  17042  10865   551920
# 147           TIGER 200 에너지화학  139250        섹터/소재    333  21280    66027
#
#        수익율   총보수       운용사
# 31   60.47  0.40  미래에셋자산운용
# 21   54.25  0.45    삼성자산운용
# 24   51.71  0.40  미래에셋자산운용
# 237  51.02  0.15    삼성자산운용
# 210  50.65  0.19   케이비자산운용
# 127  46.49  0.15  미래에셋자산운용
# 29   45.04  0.50  미래에셋자산운용
# 461  44.87  0.40    한화자산운용
# 130  44.80  0.45    삼성자산운용
# 58   44.57  0.45    삼성자산운용
# 327  44.04  0.40   케이비자산운용
# 334  43.88  0.40  미래에셋자산운용
# 70   43.78  0.15   케이비자산운용
# 20   43.65  0.15  미래에셋자산운용
# 96   43.60  0.25   케이비자산운용
# 435  42.44  0.19   케이비자산운용
# 225  42.18  0.15  미래에셋자산운용
# 66   42.13  0.15  한국투자신탁운용
# 6    41.10  0.25    삼성자산운용
# 147  40.88  0.40  미래에셋자산운용

# %% [markdown]
# ### 금일 ETF 수익율 순위 확인

# %%
import requests
import json
from pandas import json_normalize
url = 'https://finance.naver.com/api/sise/etfItemList.nhn'
json_data = json.loads(requests.get(url).text)
df2 = json_normalize(json_data['result']['etfItemList'])
df2.sort_values('changeRate',ascending=False)[:10]
df2.columns = ['code','TabCode','이름','현재가','등/락','가격변동','일수익율','일평균가','3개월수익율','거래량/일','거래금액/일,백만','marketSum']
df2 = df2.fillna(0)
df2['3개월수익율'] = df2['3개월수익율'].round(1)
df3 = df2[['code','일수익율','가격변동','거래금액/일,백만']]
li_df = df2.sort_values('일수익율',ascending=False)[:20]
li_df 
# df.to_excel('etf_list.xlsx',header=True,index=False);
# Out:
#        code  TabCode                        이름    현재가 등/락  가격변동  일수익율  \
# 236  271060        5          KODEX 3대농산물선물(H)  10205   2   585  6.08
# 94   219390        4  KBSTAR 미국S&P원유생산기업(합성 H)   3100   2   155  5.26
# 117  137610        5    TIGER 농산물선물Enhanced(H)   5695   2   270  4.98
# 321  138920        5              KODEX 콩선물(H)  11730   2   370  3.26
# 210  228790        2                 TIGER 화장품   3565   2   100  2.89
# 343  170350        2               TIGER 베타플러스  20015   2   550  2.83
# 72   130680        5     TIGER 원유선물Enhanced(H)   2430   2    65  2.75
# 226  243890        2        TIGER 200에너지화학레버리지  23685   2   595  2.58
# 31   261220        5          KODEX WTI원유선물(H)   8075   2   195  2.47
# 221  218420        4        KODEX 미국S&P에너지(합성)   5565   2   130  2.39
# 262  159800        1                마이티 코스피100  33375   2   755  2.31
# 439  091220        2                  TIGER 은행   7000   2   150  2.19
# 44   091170        2                  KODEX 은행   6745   2   140  2.12
# 396  295820        1           ARIRANG 200동일가중  10705   2   220  2.10
# 182  139270        2              TIGER 200 금융   6680   2   135  2.06
# 436  284990        2           KBSTAR 200에너지화학  13990   2   270  1.97
# 459  139310        5             TIGER 금속선물(H)   5745   2   110  1.95
# 120  228810        2              TIGER 미디어컨텐츠   6410   2   120  1.91
# 104  243880        2           TIGER 200IT레버리지  73360   2  1365  1.90
# 107  289260        2   TIGER MSCI KOREA ESG리더스  12110   2   220  1.85
#
#         일평균가  3개월수익율    거래량/일  거래금액/일,백만  marketSum
# 236      0.0    18.1   182739       1856        156
# 94       0.0    43.3   801331       2487        687
# 117      0.0    16.5   229650       1301        495
# 321      0.0    26.5    22832        269         94
# 210   3568.0    -4.3   428109       1518        183
# 343  19987.0    39.7     1000         20         84
# 72       0.0    20.7  1376989       3330       1137
# 226  23788.0    88.7    60503       1446        166
# 31       0.0    26.2  2195385      17664       4330
# 221      0.0    28.9   125155        694        175
# 262  33434.0    32.7       94          3        134
# 439   7010.0    22.1   171318       1191         46
# 44    6745.0    23.0  1605920      10828       2182
# 396  10686.0    20.4       30          0         64
# 182   6679.0    21.7    83344        557        232
# 436  14009.0    37.7     5385         75         48
# 459      0.0    12.0     6948         39         34
# 120   6435.0     6.2  1206355       7675        471
# 104  73290.0   117.0    45013       3297        624
# 107  12113.0    30.9     1485         17        589

# %%
def price_plot(codes,period):
    from datetime import datetime,timedelta
    import FinanceDataReader as fdr
    for code in codes:
        df = pd.read_csv(etf, encoding = 'euckr', index_col=0)
        df['코드'] = df['코드'].astype(str)
        temp = [i for i in df[df['코드'].apply(lambda x: len(x))<=5].index]
        df.loc[temp,'코드'] = '0'+ df.loc[temp,'코드'].astype(str)
        e_date = datetime.now()
        s_date = e_date - timedelta(int(period))
        df_temp = fdr.DataReader(code, s_date ,e_date)
        name = df[df.코드 == code].종목명.values[0]
        df_kospi = fdr.DataReader('KS11', s_date ,e_date)
        df_temp['p_index'] = df_temp['Close'].apply(lambda x: x/df_temp.iloc[0,3])
        df_temp['p_index'].plot(legend = 'a',label= name, figsize=(16,8))
    df_kospi['p_index'] = df_kospi['Close'].apply(lambda x: x/df_kospi.iloc[0,3])
    df_kospi['p_index'].plot(color = 'grey',legend = 'a',label= 'KOSPI지수', figsize=(16,8))
        
# 다중 차트 만드는 함수  
def price_plot_s(codes,period,row,col, fig = (16,8)):
    import pandas as pd
    from datetime import datetime,timedelta
    import FinanceDataReader as fdr
    import matplotlib.pyplot as plt
    for idx, code in enumerate(codes):
        df = pd.read_csv(etf, encoding = 'euckr', index_col=0)
        df['코드'] = df['코드'].astype(str)
        temp = [i for i in df[df['코드'].apply(lambda x: len(x))<=5].index]
        df.loc[temp,'코드'] = '0'+ df.loc[temp,'코드'].astype(str)
        e_date = datetime.now()
        s_date = e_date - timedelta(int(period))
        df_temp = fdr.DataReader(code, s_date ,e_date)
        df_kospi = fdr.DataReader('KS11', s_date ,e_date)
        name = df[df.코드 == code].종목명.values[0]
                
        plt.subplot(row,col,idx+1) # subplot : 도화지를 나눔, 1행/2열로 나누고 첫번째도화지에...
        df_temp['p_index'] = df_temp['Close'].apply(lambda x: x/df_temp.iloc[0,3])
        df_temp['p_index'].plot(legend = 'a',label= name, figsize=fig)
        df_kospi['p_index'] = df_kospi['Close'].apply(lambda x: x/df_kospi.iloc[0,3])
        df_kospi['p_index'].plot(color = 'grey', legend = 'a',label= 'KOSPI지수', figsize=fig)

# 코드 리스트로 df 불러오기
def price_codes(codes, period):
    import pandas as pd
    import FinanceDataReader as fdr
    from datetime import datetime,timedelta
    import matplotlib.pyplot as plt
    df = pd.read_csv(etf, encoding = 'euckr', index_col=0)
    df['코드'] = df['코드'].astype(str)
    temp = [i for i in df[df['코드'].apply(lambda x: len(x))<=5].index]
    df.loc[temp,'코드'] = '0'+ df.loc[temp,'코드'].astype(str)

    e_date = datetime.now()
    s_date = e_date - timedelta(int(period))
    
    df_m = pd.DataFrame()
    df_m_index = pd.DataFrame()
    
    for code in codes:
        df_temp = fdr.DataReader(code, s_date ,e_date)
        name = df[df.코드 == code].종목명.values[0]
        df_temp['p_index'] = df_temp['Close'].apply(lambda x: x/df_temp.iloc[0,3])
        df_m[name] = df_temp['Close']
        df_m_index[name] = df_temp['p_index']
    df_kospi = fdr.DataReader('KS11', s_date ,e_date)
    df_cur = fdr.DataReader('USD/KRW', s_date ,e_date)
    df_kospi['p_index'] = df_kospi['Close'].apply(lambda x: x/df_kospi.iloc[0,3])
    df_cur['p_index'] = df_cur['Close'].apply(lambda x: x/df_cur.iloc[0,3])
    df_m_index['KOSPI'] = df_kospi['p_index'] 
    df_m_index['USD/KRW'] = df_cur['p_index'] 
    
    return df_m, df_m_index  
        
# 특정텍스트 포함 조건식을 걸어서 가격 df를 만드는 함수
def price_texts(유형,종목명, period):
    import pandas as pd
    import FinanceDataReader as fdr
    from datetime import datetime,timedelta
    import matplotlib.pyplot as plt
    df = pd.read_csv(etf, encoding = 'euckr', index_col=0)
    df['코드'] = df['코드'].astype(str)
    temp = [i for i in df[df['코드'].apply(lambda x: len(x))<=5].index]
    df.loc[temp,'코드'] = '0'+ df.loc[temp,'코드'].astype(str)
    
    if 유형 != 'None':
        codes = [code for code in df[df.유형.str.contains(유형)].코드]
        names = [n for n in df[df.유형.str.contains(유형)].종목명]
    elif 종목명 != 'None':
        codes = [code for code in df[df.종목명.str.contains(종목명)].코드]
        names = [n for n in df[df.종목명.str.contains(종목명)].종목명]
    print(f'해당종목은 {names}입니다.')
    e_date = datetime.now()
    s_date = e_date - timedelta(int(period))
    
    df_m = pd.DataFrame()
    df_m_index = pd.DataFrame()
    for code in codes:
        df_temp = fdr.DataReader(code, s_date ,e_date)
        name = df[df.코드 == code].종목명.values[0]
        df_temp['p_index'] = df_temp['Close'].apply(lambda x: x/df_temp.iloc[0,3])
        df_m[name] = df_temp['Close']
        df_m_index[name] = df_temp['p_index']
        
    df_kospi = fdr.DataReader('KS11', s_date ,e_date)
    df_cur = fdr.DataReader('USD/KRW', s_date ,e_date)
    df_kospi['p_index'] = df_kospi['Close'].apply(lambda x: x/df_kospi.iloc[0,3])
    df_cur['p_index'] = df_cur['Close'].apply(lambda x: x/df_cur.iloc[0,3])
    df_m_index['KOSPI'] = df_kospi['p_index'] 
    df_m_index['USD/KRW'] = df_cur['p_index'] 

    return df_m, df_m_index

# 구성종목 확인함수
def comp(codes):
    import requests
    import FinanceDataReader as fdr
    import pandas as pd
    df = pd.read_csv(etf, encoding = 'euckr', index_col=0)
    df['코드'] = df['코드'].astype(str)
    temp = [i for i in df[df['코드'].apply(lambda x: len(x))<=5].index]
    df.loc[temp,'코드'] = '0'+ df.loc[temp,'코드'].astype(str)
    
    df_l = []
    try:
        for idx, code in enumerate(codes):
            name = df[df.코드 == code].종목명.values[0]
            url = f'https://finance.naver.com/item/main.nhn?code={code}'
            html = requests.get(url).text
            dfs = pd.read_html(html)
            dfs_c = dfs[3]
            if len(dfs_c)>10 :
                if dfs_c['구성비중'][2]!='-':
                    dfs_c = dfs_c.dropna()[['구성종목(구성자산)','구성비중','등락률']]
                    dfs_c.columns = [name,f'구성비중{idx+1}',f'등락률{idx+1}']
                    df_l.append(dfs_c)
        df_m = pd.concat(df_l,axis=1)
    except:
        pass    
        df_m = pd.concat(df_l,axis=1)
    return df_m

# %%
codes =['271060','219390']
price_plot(codes,90)

# %% [markdown]
# #### 금일 상위 20개 종목 30일 차트 조회

# %%
li = [code for code in li_df.code]
price_plot_s(li,30,5,4,(32,16)) # (리스트, 일자,행,열,차트크기)

# %% [markdown]
# #### 관심종목 30일 차트 조회

# %%
li = [code for code in df1[df1.유형.str.contains('상품')].코드]
price_plot_s(li,30,4,4,(32,16))

# %% [markdown]
# #### 관심 종목 corr구하기 (kospi 비교)

# %%
# li = [code for code in df1[df1.유형.str.contains('상품')].코드]
df = price_codes(li,365)[1]
df.corr()
# Out:
#                           KODEX 3대농산물선물(H)  KBSTAR 미국S&P원유생산기업(합성 H)  \
# KODEX 3대농산물선물(H)                  1.000000                  0.245535
# KBSTAR 미국S&P원유생산기업(합성 H)          0.245535                  1.000000
# TIGER 농산물선물Enhanced(H)            0.993708                  0.307663
# KODEX 콩선물(H)                      0.938901                  0.087534
# TIGER 화장품                         0.267841                  0.279831
# TIGER 베타플러스                       0.776525                  0.201701
# TIGER 원유선물Enhanced(H)             0.290313                  0.866020
# TIGER 200에너지화학레버리지                0.729694                  0.149447
# KODEX WTI원유선물(H)                  0.213894                  0.767499
# KODEX 미국S&P에너지(합성)               -0.042422                  0.931436
# 마이티 코스피100                        0.765684                  0.290021
# TIGER 은행                          0.716483                  0.712147
# KODEX 은행                          0.719772                  0.710752
# ARIRANG 200동일가중                   0.691854                  0.270441
# TIGER 200 금융                      0.756436                  0.665920
# KBSTAR 200에너지화학                   0.672013                  0.109022
# TIGER 금속선물(H)                     0.779763                  0.215459
# TIGER 미디어컨텐츠                      0.507425                  0.433696
# TIGER 200IT레버리지                   0.817959                  0.326194
# TIGER MSCI KOREA ESG리더스           0.692643                  0.247635
# KOSPI                             0.726044                  0.262445
# USD/KRW                          -0.854116                 -0.158100
#
#                           TIGER 농산물선물Enhanced(H)  KODEX 콩선물(H)  TIGER 화장품  \
# KODEX 3대농산물선물(H)                        0.993708      0.938901   0.267841
# KBSTAR 미국S&P원유생산기업(합성 H)                0.307663      0.087534   0.279831
# TIGER 농산물선물Enhanced(H)                  1.000000      0.926539   0.300445
# KODEX 콩선물(H)                            0.926539      1.000000   0.432884
# TIGER 화장품                               0.300445      0.432884   1.000000
# TIGER 베타플러스                             0.784736      0.906940   0.713184
# TIGER 원유선물Enhanced(H)                   0.359073      0.050179   0.073489
# TIGER 200에너지화학레버리지                      0.738905      0.875036   0.708690
# KODEX WTI원유선물(H)                        0.274060     -0.070761  -0.172839
# KODEX 미국S&P에너지(합성)                      0.018550     -0.228920   0.057241
# 마이티 코스피100                              0.781688      0.879800   0.733327
# TIGER 은행                                0.764272      0.661822   0.558679
# KODEX 은행                                0.767293      0.664614   0.556111
# ARIRANG 200동일가중                         0.709229      0.829484   0.830716
# TIGER 200 금융                            0.799857      0.722620   0.619023
# KBSTAR 200에너지화학                         0.682575      0.841573   0.769127
# TIGER 금속선물(H)                           0.797866      0.876789   0.674204
# TIGER 미디어컨텐츠                            0.544393      0.580064   0.858770
# TIGER 200IT레버리지                         0.825980      0.889169   0.577470
# TIGER MSCI KOREA ESG리더스                 0.708496      0.838508   0.778379
# KOSPI                                   0.741530      0.860400   0.775365
# USD/KRW                                -0.862896     -0.930117  -0.579461
#
#                           TIGER 베타플러스  TIGER 원유선물Enhanced(H)  \
# KODEX 3대농산물선물(H)             0.776525               0.290313
# KBSTAR 미국S&P원유생산기업(합성 H)     0.201701               0.866020
# TIGER 농산물선물Enhanced(H)       0.784736               0.359073
# KODEX 콩선물(H)                 0.906940               0.050179
# TIGER 화장품                    0.713184               0.073489
# TIGER 베타플러스                  1.000000               0.065167
# TIGER 원유선물Enhanced(H)        0.065167               1.000000
# TIGER 200에너지화학레버리지           0.982390               0.024175
# KODEX WTI원유선물(H)            -0.133533               0.962816
# KODEX 미국S&P에너지(합성)          -0.118979               0.827089
# 마이티 코스피100                   0.992430               0.154769
# TIGER 은행                     0.730784               0.604773
# KODEX 은행                     0.732584               0.604305
# ARIRANG 200동일가중              0.974130               0.103021
# TIGER 200 금융                 0.793486               0.557777
# KBSTAR 200에너지화학              0.976059              -0.026495
# TIGER 금속선물(H)                0.942984               0.180521
# TIGER 미디어컨텐츠                 0.764939               0.339295
# TIGER 200IT레버리지              0.949326               0.201932
# TIGER MSCI KOREA ESG리더스      0.985450               0.082630
# KOSPI                        0.991886               0.109823
# USD/KRW                     -0.922624              -0.107043
#
#                           TIGER 200에너지화학레버리지  KODEX WTI원유선물(H)  \
# KODEX 3대농산물선물(H)                    0.729694          0.213894
# KBSTAR 미국S&P원유생산기업(합성 H)            0.149447          0.767499
# TIGER 농산물선물Enhanced(H)              0.738905          0.274060
# KODEX 콩선물(H)                        0.875036         -0.070761
# TIGER 화장품                           0.708690         -0.172839
# TIGER 베타플러스                         0.982390         -0.133533
# TIGER 원유선물Enhanced(H)               0.024175          0.962816
# TIGER 200에너지화학레버리지                  1.000000         -0.172686
# KODEX WTI원유선물(H)                   -0.172686          1.000000
# KODEX 미국S&P에너지(합성)                 -0.161076          0.792964
# 마이티 코스피100                          0.976019         -0.051194
# TIGER 은행                            0.666186          0.445314
# KODEX 은행                            0.668314          0.445423
# ARIRANG 200동일가중                     0.956865         -0.121496
# TIGER 200 금융                        0.737974          0.387305
# KBSTAR 200에너지화학                     0.989258         -0.238287
# TIGER 금속선물(H)                       0.924989         -0.009299
# TIGER 미디어컨텐츠                        0.750817          0.115237
# TIGER 200IT레버리지                     0.933922          0.031476
# TIGER MSCI KOREA ESG리더스             0.980663         -0.136751
# KOSPI                               0.977272         -0.105343
# USD/KRW                            -0.874826          0.046618
#
#                           KODEX 미국S&P에너지(합성)  ...  KODEX 은행  ARIRANG 200동일가중  \
# KODEX 3대농산물선물(H)                   -0.042422  ...  0.719772         0.691854
# KBSTAR 미국S&P원유생산기업(합성 H)            0.931436  ...  0.710752         0.270441
# TIGER 농산물선물Enhanced(H)              0.018550  ...  0.767293         0.709229
# KODEX 콩선물(H)                       -0.228920  ...  0.664614         0.829484
# TIGER 화장품                           0.057241  ...  0.556111         0.830716
# TIGER 베타플러스                        -0.118979  ...  0.732584         0.974130
# TIGER 원유선물Enhanced(H)               0.827089  ...  0.604305         0.103021
# TIGER 200에너지화학레버리지                 -0.161076  ...  0.668314         0.956865
# KODEX WTI원유선물(H)                    0.792964  ...  0.445423        -0.121496
# KODEX 미국S&P에너지(합성)                  1.000000  ...  0.466949        -0.040709
# 마이티 코스피100                         -0.024135  ...  0.772243         0.976621
# TIGER 은행                            0.467981  ...  0.999599         0.757879
# KODEX 은행                            0.466949  ...  1.000000         0.758648
# ARIRANG 200동일가중                    -0.040709  ...  0.758648         1.000000
# TIGER 200 금융                        0.400126  ...  0.987657         0.823216
# KBSTAR 200에너지화학                    -0.201143  ...  0.645714         0.970654
# TIGER 금속선물(H)                      -0.114742  ...  0.734043         0.921863
# TIGER 미디어컨텐츠                        0.183604  ...  0.691841         0.852681
# TIGER 200IT레버리지                     0.035837  ...  0.746152         0.895645
# TIGER MSCI KOREA ESG리더스            -0.060097  ...  0.726899         0.982417
# KOSPI                              -0.050345  ...  0.752506         0.989352
# USD/KRW                             0.172044  ... -0.758075        -0.886828
#
#                           TIGER 200 금융  KBSTAR 200에너지화학  TIGER 금속선물(H)  \
# KODEX 3대농산물선물(H)              0.756436         0.672013       0.779763
# KBSTAR 미국S&P원유생산기업(합성 H)      0.665920         0.109022       0.215459
# TIGER 농산물선물Enhanced(H)        0.799857         0.682575       0.797866
# KODEX 콩선물(H)                  0.722620         0.841573       0.876789
# TIGER 화장품                     0.619023         0.769127       0.674204
# TIGER 베타플러스                   0.793486         0.976059       0.942984
# TIGER 원유선물Enhanced(H)         0.557777        -0.026495       0.180521
# TIGER 200에너지화학레버리지            0.737974         0.989258       0.924989
# KODEX WTI원유선물(H)              0.387305        -0.238287      -0.009299
# KODEX 미국S&P에너지(합성)            0.400126        -0.201143      -0.114742
# 마이티 코스피100                    0.829293         0.966523       0.944493
# TIGER 은행                      0.987360         0.644441       0.732629
# KODEX 은행                      0.987657         0.645714       0.734043
# ARIRANG 200동일가중               0.823216         0.970654       0.921863
# TIGER 200 금융                  1.000000         0.717057       0.789580
# KBSTAR 200에너지화학               0.717057         1.000000       0.924171
# TIGER 금속선물(H)                 0.789580         0.924171       1.000000
# TIGER 미디어컨텐츠                  0.765077         0.774853       0.754118
# TIGER 200IT레버리지               0.794854         0.889286       0.868966
# TIGER MSCI KOREA ESG리더스       0.786440         0.983275       0.925183
# KOSPI                         0.813644         0.978165       0.939338
# USD/KRW                      -0.803148        -0.874323      -0.930552
#
#                           TIGER 미디어컨텐츠  TIGER 200IT레버리지  \
# KODEX 3대농산물선물(H)              0.507425         0.817959
# KBSTAR 미국S&P원유생산기업(합성 H)      0.433696         0.326194
# TIGER 농산물선물Enhanced(H)        0.544393         0.825980
# KODEX 콩선물(H)                  0.580064         0.889169
# TIGER 화장품                     0.858770         0.577470
# TIGER 베타플러스                   0.764939         0.949326
# TIGER 원유선물Enhanced(H)         0.339295         0.201932
# TIGER 200에너지화학레버리지            0.750817         0.933922
# KODEX WTI원유선물(H)              0.115237         0.031476
# KODEX 미국S&P에너지(합성)            0.183604         0.035837
# 마이티 코스피100                    0.801012         0.958291
# TIGER 은행                      0.692930         0.742412
# KODEX 은행                      0.691841         0.746152
# ARIRANG 200동일가중               0.852681         0.895645
# TIGER 200 금융                  0.765077         0.794854
# KBSTAR 200에너지화학               0.774853         0.889286
# TIGER 금속선물(H)                 0.754118         0.868966
# TIGER 미디어컨텐츠                  1.000000         0.700466
# TIGER 200IT레버리지               0.700466         1.000000
# TIGER MSCI KOREA ESG리더스       0.798905         0.932096
# KOSPI                         0.819605         0.937725
# USD/KRW                      -0.664126        -0.840995
#
#                           TIGER MSCI KOREA ESG리더스     KOSPI   USD/KRW
# KODEX 3대농산물선물(H)                         0.692643  0.726044 -0.854116
# KBSTAR 미국S&P원유생산기업(합성 H)                 0.247635  0.262445 -0.158100
# TIGER 농산물선물Enhanced(H)                   0.708496  0.741530 -0.862896
# KODEX 콩선물(H)                             0.838508  0.860400 -0.930117
# TIGER 화장품                                0.778379  0.775365 -0.579461
# TIGER 베타플러스                              0.985450  0.991886 -0.922624
# TIGER 원유선물Enhanced(H)                    0.082630  0.109823 -0.107043
# TIGER 200에너지화학레버리지                       0.980663  0.977272 -0.874826
# KODEX WTI원유선물(H)                        -0.136751 -0.105343  0.046618
# KODEX 미국S&P에너지(합성)                      -0.060097 -0.050345  0.172044
# 마이티 코스피100                               0.988892  0.995125 -0.903940
# TIGER 은행                                 0.725519  0.751133 -0.756851
# KODEX 은행                                 0.726899  0.752506 -0.758075
# ARIRANG 200동일가중                          0.982417  0.989352 -0.886828
# TIGER 200 금융                             0.786440  0.813644 -0.803148
# KBSTAR 200에너지화학                          0.983275  0.978165 -0.874323
# TIGER 금속선물(H)                            0.925183  0.939338 -0.930552
# TIGER 미디어컨텐츠                             0.798905  0.819605 -0.664126
# TIGER 200IT레버리지                          0.932096  0.937725 -0.840995
# TIGER MSCI KOREA ESG리더스                  1.000000  0.994313 -0.874545
# KOSPI                                    0.994313  1.000000 -0.897408
# USD/KRW                                 -0.874545 -0.897408  1.000000
#
# [22 rows x 22 columns]

# %%
df = price_texts('None','골드',20)[1]
df.corr()
# Out:
# 해당종목은 ['KODEX 골드선물(H)', 'KINDEX 골드선물 레버리지(합성 H)', 'TIGER 골드선물(H)', 'KODEX 골드선물인버스(H)']입니다.
#                         KODEX 골드선물(H)  KINDEX 골드선물 레버리지(합성 H)  TIGER 골드선물(H)  \
# KODEX 골드선물(H)                1.000000                0.997207       0.995138
# KINDEX 골드선물 레버리지(합성 H)       0.997207                1.000000       0.991869
# TIGER 골드선물(H)                0.995138                0.991869       1.000000
# KODEX 골드선물인버스(H)            -0.995663               -0.991374      -0.991177
# KOSPI                       -0.091680               -0.110353      -0.082051
# USD/KRW                     -0.719158               -0.726562      -0.723606
#
#                         KODEX 골드선물인버스(H)     KOSPI   USD/KRW
# KODEX 골드선물(H)                  -0.995663 -0.091680 -0.719158
# KINDEX 골드선물 레버리지(합성 H)         -0.991374 -0.110353 -0.726562
# TIGER 골드선물(H)                  -0.991177 -0.082051 -0.723606
# KODEX 골드선물인버스(H)                1.000000  0.085097  0.712533
# KOSPI                           0.085097  1.000000  0.105469
# USD/KRW                         0.712533  0.105469  1.000000

# %%
li = [code for code in df1[df1.유형.str.contains('상품')].코드]
df = price_codes(li,365)[1]
df.corr()

# %%
li = [code for code in df2.code[:20]]
df_t = price_codes(li,30)
df_t[1].tail(5)
# Out:
#             KODEX 200  TIGER 200  KODEX 단기채권  TIGER MSCI Korea TR  \
# Date
# 2021-01-06   1.098975   1.098045    1.000390             1.093915
# 2021-01-07   1.124595   1.123129    1.000536             1.116402
# 2021-01-08   1.174353   1.173432    1.000536             1.172288
# 2021-01-11   1.177319   1.176129    1.000585             1.178902
# 2021-01-12   1.156149   1.155765    1.000634             1.160053
#
#             KODEX 200선물인버스2X  KODEX MSCI Korea TR  KODEX 삼성그룹  KODEX 레버리지  \
# Date
# 2021-01-06          0.822300             1.093854    1.114458    1.204087
# 2021-01-07          0.782230             1.116694    1.139650    1.262740
# 2021-01-08          0.710801             1.173588    1.190033    1.377885
# 2021-01-11          0.709059             1.183140    1.192771    1.386058
# 2021-01-12          0.735192             1.155731    1.168675    1.331490
#
#             KODEX 200TR  KODEX 종합채권(AA-이상)액티브  KBSTAR 200  KODEX 코스닥150 레버리지  \
# Date
# 2021-01-06     1.104114              0.998003    1.099407           1.067348
# 2021-01-07     1.125105              0.998638    1.125135           1.080753
# 2021-01-08     1.176742              0.998275    1.175647           1.093840
# 2021-01-11     1.178421              0.999682    1.178206           1.097670
# 2021-01-12     1.156591              0.998911    1.156519           1.079796
#
#             KODEX 인버스  KODEX 단기채권PLUS  ARIRANG 200  TIGER 단기통안채  KINDEX 200  \
# Date
# 2021-01-06   0.906593        1.000583     1.098941      1.00035    1.098724
# 2021-01-07   0.885714        1.000632     1.124413      1.00035    1.125991
# 2021-01-08   0.846154        1.000681     1.175627      1.00040    1.175688
# 2021-01-11   0.843956        1.000632     1.177236      1.00045    1.179987
# 2021-01-12   0.860440        1.000632     1.155919      1.00040    1.157690
#
#             KOSEF 200  HANARO 200  TIGER 미국나스닥100
# Date
# 2021-01-06   1.099690    1.098087        1.015955
# 2021-01-07   1.125286    1.124899        1.021971
# 2021-01-08   1.175401    1.173808        1.045293
# 2021-01-11   1.179577    1.176233        1.056665
# 2021-01-12   1.157483    1.155888        1.049166

# %% [markdown]
# #### 구성종목 확인하기

# %%
comp(['228810','228800'])
# Out:
#    TIGER 미디어컨텐츠   구성비중1    등락률1 TIGER 여행레저  구성비중2    등락률2
# 1        CJ CGV  11.62%  +7.65%      파라다이스  9.91%  +2.95%
# 2       스튜디오드래곤  11.38%  +4.33%       강원랜드  9.66%  +5.06%
# 3        CJ ENM  10.87%  +5.69%       호텔신라  9.47%  +3.91%
# 4      JYP Ent.   9.52%  +1.93%       하나투어  9.20%  +3.86%
# 5        제이콘텐트리   9.20%  +6.96%        한진칼  8.71%  +0.59%
# 9           에스엠   8.28%  -0.17%        GKL  8.20%  +2.21%
# 10    와이지엔터테인먼트   8.25%  +2.84%        아난티  8.10%  -1.10%
# 11          초록뱀   6.25%  +3.61%     롯데관광개발  7.93%  +1.01%
# 12         키이스트   4.29%   0.00%       모두투어  5.28%  +5.32%
# 13         지니뮤직   3.48%  +0.68%        진에어  4.35%  -0.62%

# %%
li = [code for code in df1[df1.종목명.str.contains('미디어')].코드]
comp(li)
# Out:
#    TIGER 미디어컨텐츠   구성비중1    등락률1 KODEX 미디어&엔터테인먼트   구성비중2    등락률2
# 1        CJ CGV  12.04%  +0.53%              카카오  23.89%  -0.66%
# 2       스튜디오드래곤  11.43%  -0.10%            엔씨소프트  18.18%  -1.37%
# 3        CJ ENM  11.05%  -0.53%            NAVER  17.85%  +3.29%
# 4        제이콘텐트리   9.47%  -2.46%              넷마블  14.65%  +1.60%
# 5      JYP Ent.   9.34%  +0.54%             펄어비스   2.99%  +0.04%
# 9     와이지엔터테인먼트   8.16%  +3.87%             제일기획   2.59%  +3.64%
# 10          에스엠   7.95%  +5.53%              컴투스   2.59%  +2.34%
# 11          초록뱀   6.23%  +2.24%          스튜디오드래곤   2.21%  -0.10%
# 12         키이스트   4.13%  +1.40%           카카오게임즈   1.99%  +1.30%
# 13      위지윅스튜디오   3.51%  +1.82%         JYP Ent.   1.79%  +0.54%

# %%
comp([code for code in df1[df1.유형.str.contains('우량주')].코드])
# Out:
#    TIGER TOP10   구성비중1    등락률1 KODEX KTOP30   구성비중2    등락률2 TIGER KTOP30  \
# 1         삼성전자  25.58%  -0.44%         삼성전자  23.07%  -0.44%         삼성전자
# 2       SK하이닉스  15.59%  -3.01%         LG화학  10.10%  -3.61%         LG화학
# 3         LG화학   9.84%  -3.61%        NAVER   7.83%  -1.62%        NAVER
# 4        NAVER   8.59%  -1.62%        삼성SDI   7.39%  +2.05%        삼성SDI
# 5         셀트리온   8.48%  +2.67%          카카오   4.59%  +0.99%          카카오
# 9          현대차   8.19%  -2.43%         유한양행   3.90%  -0.95%         셀트리온
# 10       삼성SDI   8.04%  +2.05%         셀트리온   3.86%  +2.67%         유한양행
# 11         카카오   5.98%  +0.99%        현대모비스   3.57%  -5.82%        현대모비스
# 12       현대모비스   4.88%  -5.82%      SK이노베이션   2.98%  -3.23%      SK이노베이션
# 13       엔씨소프트   3.88%  -3.17%        롯데케미칼   2.91%  +8.87%        롯데케미칼
#
#      구성비중3    등락률3 TIGER 우량가치  ...    등락률4 KOSEF 블루칩  구성비중5    등락률5  \
# 1   23.08%  -0.44%       한화생명  ...  -4.19%   SK이노베이션  3.46%  -3.23%
# 2   10.14%  -3.61%        현대차  ...  -2.43%      LG전자  3.10%  -2.46%
# 3    7.85%  -1.62%         CJ  ...  -0.20%     현대모비스  3.03%  -5.82%
# 4    7.42%  +2.05%        이마트  ...  +5.48%       현대차  2.97%  -2.43%
# 5    4.60%  +0.99%      효성중공업  ...  -2.36%        LG  2.84%  -0.97%
# 9    3.80%  +2.67%       현대제철  ...  -2.52%     삼성SDI  2.75%  +2.05%
# 10   3.72%  -0.95%        기아차  ...  +0.14%      삼성전자  2.64%  -0.44%
# 11   3.58%  -5.82%      SK렌터카  ...  +2.97%      한국전력  2.54%  -0.57%
# 12   2.99%  -3.23%       효성화학  ...  +0.85%   LG디스플레이  2.53%  +2.04%
# 13   2.92%  +8.87%     현대그린푸드  ...  +1.91%      삼성물산  2.51%  -3.32%
#
#    KODEX FnKorea50  구성비중6    등락률6 KBSTAR 우량업종  구성비중7    등락률7
# 1          SK이노베이션  2.74%  -3.23%        LG전자  2.98%  -2.46%
# 2             LG전자  2.64%  -2.46%       현대모비스  2.90%  -5.82%
# 3              현대차  2.47%  -2.43%         현대차  2.81%  -2.43%
# 4               LG  2.41%  -0.97%          LG  2.72%  -0.97%
# 5            삼성SDI  2.33%  +2.05%       삼성SDI  2.63%  +2.05%
# 9             삼성전자  2.21%  -0.44%        삼성전자  2.50%  -0.44%
# 10            LG화학  2.19%  -3.61%       한화솔루션  2.46%  -5.46%
# 11             카카오  2.15%  +0.99%        LG화학  2.43%  -3.61%
# 12            삼성물산  2.13%  -3.32%       두산퓨얼셀  2.43%  -4.70%
# 13              SK  2.12%  -2.93%        삼성물산  2.41%  -3.32%
#
# [10 rows x 21 columns]

# %%
comp([code for code in df2.sort_values('일수익율',ascending=False)[:20].code])
# Out:
#    TIGER 화장품   구성비중5    등락률5 TIGER 베타플러스   구성비중6    등락률6 마이티 코스피100  구성비중11  \
# 1       아모레G  11.86%  +3.61%        삼성전자  25.88%  -1.21%       삼성전자  33.17%
# 2     아모레퍼시픽  11.85%  +4.19%      SK하이닉스  14.29%  +2.33%     SK하이닉스   6.29%
# 3       한국콜마  10.83%  +1.37%       삼성SDI   7.88%  +0.67%       LG화학   3.82%
# 4     LG생활건강  10.45%  +2.12%         현대차   7.56%  -0.96%       셀트리온   3.51%
# 5       코스맥스   7.96%  +2.78%       현대모비스   4.35%  +1.96%      NAVER   3.35%
# 9    콜마비앤에이치   7.62%  +0.60%         기아차   3.62%  +2.85%      삼성SDI   3.29%
# 10   한국콜마홀딩스   7.02%  +2.10%        KB금융   3.04%  +2.27%        현대차   3.19%
# 11   현대바이오랜드   6.69%   0.00%        삼성물산   2.89%  +0.69%        카카오   2.47%
# 12       네오팜   3.99%  +6.08%        신한지주   2.88%  +3.17%      현대모비스   1.87%
# 13      코리아나   3.19%  +3.02%      하나금융지주   2.15%  +2.68%      POSCO   1.66%
#
#      등락률11 TIGER 은행  ...   등락률15 KBSTAR 200에너지화학  구성비중16   등락률16 TIGER 미디어컨텐츠  \
# 1   -1.21%   하나금융지주  ...  +2.27%            LG화학  20.22%  +3.74%       CJ CGV
# 2   +2.33%     KB금융  ...  +3.17%         SK이노베이션  20.01%  -1.23%      스튜디오드래곤
# 3   +3.74%     신한지주  ...  +2.68%              SK  13.16%  +4.97%       CJ ENM
# 4   -0.39%   우리금융지주  ...  +1.33%           한화솔루션   7.34%  +2.23%       제이콘텐트리
# 5   +3.29%     기업은행  ...  +1.36%           롯데케미칼   6.81%  -1.12%     JYP Ent.
# 9   +0.67%  BNK금융지주  ...  +3.91%           S-Oil   4.25%  +4.26%    와이지엔터테인먼트
# 10  -0.96%  DGB금융지주  ...  -0.50%            금호석유   3.84%  +1.25%          에스엠
# 11  -0.66%   JB금융지주  ...  +1.05%           SK케미칼   3.65%  +0.42%          초록뱀
# 12  +1.96%      NaN  ...  -0.57%             SKC   2.70%  -1.19%         키이스트
# 13  +1.99%      NaN  ...  +2.30%             OCI   2.61%  +4.37%      위지윅스튜디오
#
#     구성비중18   등락률18 TIGER MSCI KOREA ESG리더스  구성비중20   등락률20
# 1   12.04%  +0.53%                  SK하이닉스  16.53%  +2.33%
# 2   11.43%  -0.10%                    LG화학  10.23%  +3.74%
# 3   11.05%  -0.53%                   삼성SDI   9.59%  +0.67%
# 4    9.47%  -2.46%                   NAVER   8.76%  +3.29%
# 5    9.34%  +0.54%                    KB금융   4.28%  +2.27%
# 9    8.16%  +3.87%                 SK이노베이션   3.74%  -1.23%
# 10   7.95%  +5.53%                   엔씨소프트   3.71%  -1.37%
# 11   6.23%  +2.24%                  LG생활건강   3.49%  +2.12%
# 12   4.13%  +1.40%                    LG전자   3.45%  +1.08%
# 13   3.51%  +1.82%                    신한지주   3.41%  +3.17%
#
# [10 rows x 30 columns]

# %%
# 추출 및 수집 : 최초원본 
# from selenium import webdriver
# from bs4 import BeautifulSoup
# import time
# import pandas as pd
# import os

# PROJECT_ROOT_DIR = "./fdr_output"
# CHAPTER_ID = "stock_check"
# SAMPLES_PATH = os.path.join(PROJECT_ROOT_DIR, "samples", CHAPTER_ID)
# os.makedirs(SAMPLES_PATH, exist_ok=True)

# def mkfile(file): #파일 경로 생성함수
#     file = os.path.join(SAMPLES_PATH,f'{file}.csv')
#     return file

# etf = mkfile('etf') 

# try:
#     # 홈페이지에 접근하여 ETF 항목 클릭
#     driver=webdriver.Chrome("./chromedriver.exe")
#     driver.get("http://seibro.or.kr/websquare/control.jsp?w2xPath=/IPORTAL/user/etf/BIP_CNTS06025V.xml&menuNo=174")
#     time.sleep(5)
#     a=driver.find_element_by_xpath('//*[@id="image10"]')
#     a.click()
#     path = 'ETF.txt'
#     if os.path.exists(path):os.remove(path)

#     # 페이지 넘김
#     i=1

#     while True: 
#         time.sleep(1)
#         a=driver.find_element_by_xpath('//*[@id="pageList1_page_%d"]'%i)
#         a.click()

#         time.sleep(2)
#         html=driver.page_source
#         soup=BeautifulSoup(html,"html.parser")

#         f = open("ETF.txt", 'a')
#         for anchors in soup.select("#grid1_body_tbody")[0]:
#             for anchor in anchors.select("td"):
#                 data = anchor.get_text()+'\n'
#                 f.write(data)
#         f.close()
#         i+=1
    
    
# # 더이상 읽을 테이지 없을 때, 
# except:
#     # 리스트화 하여 항목을 담아주고, 딕셔너리로 변환하여, 판다스 DF만들기
#     df = pd.DataFrame()
#     cols = ['종목명','코드','유형','순자산','종가','거래량','수익율','총보수','운용사']
#     종목명 = [] #1;
#     코드 = [] #2
#     유형 = [] #3
#     순자산 =[] #4
#     종가 =[] #5
#     거래량 = [] #6
#     수익율 = [] #9
#     총보수 = [] #15
#     운용사 = [] #16
#     with open('ETF.txt','r') as f:
#         data = f.readlines()
#         for i, j in enumerate(data):
#             if i % 17 == 1:종목명.append(j.replace('\n',''))
#             elif i % 17 ==2:코드.append(j.replace('\n',''))
#             elif i % 17 ==3:유형.append(j.replace('\n',''))
#             elif i % 17 ==4:순자산.append(j.replace('\n',''))
#             elif i % 17 ==5:종가.append(j.replace('\n',''))
#             elif i % 17 ==6:거래량.append(j.replace('\n',''))
#             elif i % 17 ==9:수익율.append(j.replace('\n',''))
#             elif i % 17 ==15:총보수.append(j.replace('\n',''))
#             elif i % 17 ==16:운용사.append(j.replace('\n',''))      
#     data = {'종목명':종목명,'코드':코드,'유형':유형,'순자산':순자산,'종가':종가,'거래량':거래량,'수익율':수익율,'총보수':총보수,'운용사':운용사}
#     df = pd.DataFrame(data, columns = cols)

#     # 보수, 수익율 없는 상품 제거하기
#     df = df.drop(df[df['총보수']==''].index)
#     df = df.drop(df[df['수익율']==''].index)

#     # 전처리 : 계산 가능한 값으로 변환하기
#     df['거래량']=df['거래량'].apply(lambda x: x.replace(',',''))
#     df['종가']=df['종가'].apply(lambda x: x.replace(',',''))
#     df['순자산']=df['순자산'].apply(lambda x: x.replace(',',''))
#     df['거래량']=df['거래량'].astype(int)
#     df['종가']=df['종가'].astype(int)
#     df['순자산']=df['순자산'].astype(int)
#     df['수익율']=df['수익율'].astype(float)
#     df['총보수']=df['총보수'].astype(float)

#     # 전처리 : 5개 자리인 코드를 6개자리로 변환
#     df['코드'] = df['코드'].astype(str)
#     code = [i for i in df[df['코드'].apply(lambda x: len(x))<=5].index]
#     df.loc[code,'코드'] = '0'+ df.loc[code,'코드'].astype(str)

#     df.to_csv(etf,sep=',',encoding='euc-kr')
    
#     print('연산이 끝났습니다')
#     print(f'추출한 총 ETF의 수 {len(df)}개')
