# %%
from bs4 import BeautifulSoup
import requests
url = 'http://naver.com'
html = requests.get(url).text
soup = BeautifulSoup(html, 'html.parser')
soup.find_all('div')[61].text
# Out:
# '  연합뉴스  [Q&A] 다음달 11일부터 소상공인 지원금 지급…누가 얼마나 받나\n한국갤럽 "국민 87%, 코로나19 백신 접종하겠다"\n동부구치소 첫 코로나 사망자는 \'굿모닝시티 분양사기\' 윤창열\n박원순 피해자측 "경찰, 확인된 사실은 밝혔어야"\n\'秋 비판 검사 사표받아야\' 청원에 靑 "검사들도 자성해야"\n검찰, 이용구 \'택시기사 폭행\' 고발사건 직접 수사\n"내년 서울 집값 1.5%, 전셋값 3.6% 상승 전망"\n내일 최저 영하 17도 강추위…전라 서부 30㎝ 이상 눈\n현 마포구의원, 심야 파티룸서 \'5명 모임\' 적발돼\n\'골목식당\' 유명 돈가스집 코로나에도 장사진…결국 임시휴업    네이버뉴스\n연예\n스포츠\n경제  '

# %%
# //*[@id="themecast"]/div[2]/div[2]/div/ul/li[1]/a[2]/p/text()

# %%
soup.find_all('ul',{'class' : 'list_theme'})[2].find_all('li',{'class' : 'theme_item'})
# Out:
# [<li class="theme_item" data-da-position="true" data-gdid="CAS_73a48d81-457b-11eb-aa73-b550fe3f45b0">
#  <a class="theme_thumb" data-clk="tcc_des.list3cont1" href="https://post.naver.com/viewer/postView.nhn?volumeNo=30249377" target="_blank">
#  <img alt="영화 '러브액츄얼리'에서 영감 받은 연희동 주택" data-src="https://s.pstatic.net/dthumb.phinf/?src=%22https%3A%2F%2Fs.pstatic.net%2Fstatic%2Fwww%2Fmobile%2Fedit%2F2020%2F1225%2Fupload_24787650022866362PJyF2.jpg%22&amp;type=nf340_228" height="114" width="170"/>
#  <span class="thumb_bd"></span>
#  </a>
#  <a class="theme_info" data-clk="tcc_des.list3cont1" href="https://post.naver.com/viewer/postView.nhn?volumeNo=30249377" target="_blank">
#  <em class="theme_category"> 디자인</em>
#  <strong class="title elss">영화 '러브액츄얼리'에서 영감 받은 연희동 주택</strong>
#  <p class="desc">편집자주 집은 ‘사고 파는 것’이기 전에 ‘삶을 사는 곳’입니다. 집에 맞춘 삶을 살고 있지는 않나요? 삶에, 또한 사람에 맞춰 지은 전국의 집을 찾아 소개하는 기획을 수요일 격주로 &lt;한국일보&gt;에 연재합니다.집은 영화 ‘러브 액츄얼리’ 속 한 장면에서 시작했다. 사랑하는 여성을 찾으</p>
# ...

# %%
url = 'https://news.naver.com/main/list'
html = requests.get(url).text
soup = BeautifulSoup(html, 'html.parser')
# id="main_content"
soup.find_all('div',{'id' : 'main_content'})
# Out:
# ---------------------------------------------------------------------------
# RemoteDisconnected                        Traceback (most recent call last)
# C:\Dev\Miniconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     669             # Make the request on the httplib connection object.
# --> 670             httplib_response = self._make_request(
#     671                 conn,
#
# C:\Dev\Miniconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     425                     # Otherwise it looks like a bug in the code.
# --> 426                     six.raise_from(e, None)
#     427         except (SocketTimeout, BaseSSLError, SocketError) as e:
#
# C:\Dev\Miniconda3\lib\site-packages\urllib3\packages\six.py in raise_from(value, from_value)
#
# ...
