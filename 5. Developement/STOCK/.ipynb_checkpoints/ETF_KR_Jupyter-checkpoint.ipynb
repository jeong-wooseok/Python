# %% [markdown]
# ### 기본설정

# %% [markdown]
#  <br>
# 크롬 버전에 맞춰서 웹브라우저를 다운 받아야 합니다.
#
# 크롬 버전 확인하는 방법입니다.
# 크롬을 열어준후 설정에서 설치된 크롬의 버전의 확인합니다.
#
# ![크롬버전 확인하기1](https://github.com/jeong-wooseok/Python/blob/master/img/img_20201227_5.png?raw=true)
#
# ![크롬버전 확인하기2](https://github.com/jeong-wooseok/Python/blob/master/img/img_20201227_6.png?raw=true)
#
# [크롬드라이버다운로드 바로가기](https://chromedriver.chromium.org/downloads)
# <br>
# 소수점 앞의 두자리가 동일한 것으로 다운로드 합니다.
#
# ![크롬버전 확인하기2](https://github.com/jeong-wooseok/Python/blob/master/img/img_20201227_7.png?raw=true)

# %% [markdown]
# 현재 파일 경로를 확인하고, 크롬 드라이버를 넣어줍니다.

# %%
pwd
# Out:
# 'C:\\Users\\Administrator'

# %% [markdown]
# ### 크롤링을 통해 ETF 데이터 가져오기

# %% [markdown]
# 파이썬의 라이브러리인 셀레니움을 사용하여 크롤링을 진행합니다.
# 한국예탁결제원의 증권정보포탈 사이트를 참조합니다.

# %%
from selenium import webdriver
from bs4 import BeautifulSoup
import time
import pandas as pd
import os

try:
    # 홈페이지에 접근하여 ETF 항목 클릭
    driver=webdriver.Chrome("./chromedriver.exe")
    driver.get("http://seibro.or.kr/websquare/control.jsp?w2xPath=/IPORTAL/user/etf/BIP_CNTS06025V.xml&menuNo=174")
    time.sleep(5)
    a=driver.find_element_by_xpath('//*[@id="image10"]')
    a.click()
    path = 'ETF.txt'
    if os.path.exists(path):os.remove(path)

    # 페이지 넘김
    i=1

    while True: 
        time.sleep(1)
        a=driver.find_element_by_xpath('//*[@id="pageList1_page_%d"]'%i)
        a.click()

        time.sleep(2)
        html=driver.page_source
        soup=BeautifulSoup(html,"html.parser")

        f = open("ETF.txt", 'a')
        for anchors in soup.select("#grid1_body_tbody")[0]:
            for anchor in anchors.select("td"):
                data = anchor.get_text()+'\n'
                f.write(data)
        f.close()
        i+=1
    
    
# 더이상 읽을 테이지 없을 때, 
except:
    # 리스트화 하여 항목을 담아주고, 딕셔너리로 변환하여, 판다스 DF만들기
    종목명 = [] #1;
    코드 = [] #2
    유형 = [] #3
    순자산 =[] #4
    종가 =[] #5
    거래량 = [] #6
    수익율 = [] #9
    총보수 = [] #15
    운용사 = [] #16
    with open('ETF.txt','r') as f:
        data = f.readlines()
        for i, j in enumerate(data):
            if i % 17 == 1:종목명.append(j.replace('\n',''))
            elif i % 17 ==2:코드.append(j.replace('\n',''))
            elif i % 17 ==3:유형.append(j.replace('\n',''))
            elif i % 17 ==4:순자산.append(j.replace('\n',''))
            elif i % 17 ==5:종가.append(j.replace('\n',''))
            elif i % 17 ==6:거래량.append(j.replace('\n',''))
            elif i % 17 ==9:수익율.append(j.replace('\n',''))
            elif i % 17 ==15:총보수.append(j.replace('\n',''))
            elif i % 17 ==16:운용사.append(j.replace('\n',''))      
    data = {'종목명':종목명,'코드':코드,'유형':유형,'순자산':순자산,'종가':종가,'거래량':거래량,'수익율':수익율,'총보수':총보수,'운용사':운용사}
    df = pd.DataFrame(data, columns=['종목명','코드','유형','순자산','종가','거래량','수익율','총보수','운용사'])

    # 보수, 수익율 없는 상품 제거하기
    df = df.drop(df[df['총보수']==''].index)
    df = df.drop(df[df['수익율']==''].index)

    # 전처리 : 계산 가능한 값으로 변환하기
    df['거래량']=df['거래량'].apply(lambda x: x.replace(',',''))
    df['종가']=df['종가'].apply(lambda x: x.replace(',',''))
    df['순자산']=df['순자산'].apply(lambda x: x.replace(',',''))
    df['거래량']=df['거래량'].astype(int)
    df['종가']=df['종가'].astype(int)
    df['순자산']=df['순자산'].astype(int)
    df['수익율']=df['수익율'].astype(float)
    df['총보수']=df['총보수'].astype(float)

    # 전처리 : 5개 자리인 코드를 6개자리로 변환
    df['코드'] = df['코드'].astype(str)
    code = [i for i in df[df['코드'].apply(lambda x: len(x))<=5].index]
    df.loc[code,'코드'] = '0'+ df.loc[code,'코드'].astype(str)

    df.to_csv('./ETF.csv',sep=',',encoding='euc-kr')
    
    print('연산이 끝났습니다')
    print(f'추출한 총 ETF의 수 {len(df)}개')
# Out:
# 연산이 끝났습니다
# 추출한 총 ETF의 수 450개

# %% [markdown]
# ### 파생상품 제외한 목록 만들기 (연금계좌 활용)

# %%
a = ['파생상품/레버리지','파생상품/인버스']
df1 = df[~df['유형'].isin(a)]
df1['유형'].unique()
# Out:
# array(['시장지수/코스피200', '채권/단기자금', '시장지수/MSCI Korea Index', '채권/회사채권',
#        '그룹주/삼성', '해외지수/해외지수', '상품/원유', '시장지수/코스닥', '테마/우량주', '섹터/IT',
#        '테마/기타', '스타일/스타일', '상품/금속', '채권/국공채권', '섹터/금융', '섹터/경기소비재',
#        '테마/SRI', '섹터/의료', '시장지수/KRX300', '기타/기타', '통화/미국달러', '상품/농산물',
#        '투자전략/투자전략', '섹터/소재', '그룹주/현대차', '섹터/산업재', '파생상품/구조화', '섹터/필수소비재',
#        '시장지수/코스피50', '그룹주/기타', '시장지수/코스피100', '시장지수/KRX100', '통화/기타통화',
#        '그룹주/LG', '섹터/통신서비스'], dtype=object)

# %% [markdown]
# #### 연금계좌 활용용 ETF : 3개월 수익율 순위

# %%
df1.to_csv('./ETF_IRP.csv',sep=',',encoding='euc-kr')
df1.sort_values('수익율',ascending =False)[:10]
# Out:
#                           종목명      코드         유형   순자산     종가      거래량    수익율  \
# 196         KODEX 미국러셀2000(H)  280930  해외지수/해외지수   189  13125    18416  38.67
# 100  KBSTAR 미국S&P원유생산기업(합성 H)  219390  해외지수/해외지수   606   2615   581464  35.49
# 34               KODEX 2차전지산업  305720      테마/기타  3317  15040  1600151  33.57
# 329                TIGER 라틴35  105010  해외지수/해외지수    85   3245    40713  33.54
# 388                  KODEX 운송  140710     섹터/산업재    64   4550   104667  33.24
# 193        KODEX 미국S&P바이오(합성)  185680  해외지수/해외지수   191  36840     1879  32.02
# 26               TIGER 200 IT  139260      섹터/IT  4258  33255   381483  30.23
# 72            KINDEX 삼성그룹섹터가중  108450     그룹주/삼성  1074  15100    21457  30.17
# 320                  KODEX 철강  117680      섹터/소재    89   7025    48240  30.09
# 152           TIGER 200 에너지화학  139250      섹터/소재   304  17235    57801  29.98
#
#       총보수       운용사
# 196  0.45    삼성자산운용
# 100  0.25   케이비자산운용
# 34   0.45    삼성자산운용
# 329  0.49  미래에셋자산운용
# 388  0.45    삼성자산운용
# 193  0.25    삼성자산운용
# 26   0.40  미래에셋자산운용
# 72   0.15  한국투자신탁운용
# 320  0.45    삼성자산운용
# 152  0.40  미래에셋자산운용

# %% [markdown]
# ### 금일 ETF 수익율 순위 확인

# %%
import requests
import json
from pandas import json_normalize
url = 'https://finance.naver.com/api/sise/etfItemList.nhn'
json_data = json.loads(requests.get(url).text)
df2 = json_normalize(json_data['result']['etfItemList'])
df2.sort_values('changeRate',ascending=False)[:10]
df2.columns = ['code','TabCode','이름','현재가','등/락','가격변동','일수익율','일평균가','3개월수익율','거래량/일','거래금액/일,백만','marketSum']
df2 = df2.fillna(0)
df2['3개월수익율'] = df2['3개월수익율'].round(1)
df3 = df2[['code','일수익율','가격변동','거래금액/일,백만']]
df3['코드'] = df3['code']
df2.sort_values('일수익율',ascending=False)[:50]
# df.to_excel('etf_list.xlsx',header=True,index=False);
# Out:
# <ipython-input-54-a3e00e12d0e1>:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['코드'] = df3['code']
#        code  TabCode                        이름    현재가 등/락  가격변동  일수익율  \
# 101  219390        4  KBSTAR 미국S&P원유생산기업(합성 H)   2615   2   130  5.23
# 120  304780        1          HANARO 200선물레버리지  23615   2   985  4.35
# 266  307010        3         KBSTAR KRX300레버리지  17110   2   710  4.33
# 67   130680        5     TIGER 원유선물Enhanced(H)   2185   2    90  4.30
# 244  253150        3         ARIRANG 200선물레버리지  39085   2  1600  4.27
# 294  152500        3               KINDEX 레버리지   8525   2   345  4.22
# 139  252400        3          KBSTAR 200선물레버리지  19720   2   790  4.17
# 167  123320        3                TIGER 레버리지  20405   2   810  4.13
# 171  253250        3           KOSEF 200선물레버리지  19430   2   750  4.01
# 23   261220        5          KODEX WTI원유선물(H)   7280   2   280  4.00
# 205  306950        3          KODEX KRX300레버리지  17235   2   650  3.92
# 74   267770        3           TIGER 200선물레버리지  16190   2   605  3.88
# 7    122630        3                KODEX 레버리지  21545   2   770  3.71
# 232  225050        4     TIGER 유로스탁스레버리지(합성 H)   7390   2   180  2.50
# 383  289250        2  TIGER MSCI KOREA ESG유니버설  11460   2   280  2.50
# 4    310970        1       TIGER MSCI Korea TR  15435   2   370  2.46
# 217  304760        1             HANARO KRX300  17485   2   410  2.40
# 191  292730        1              FOCUS KRX300  17760   2   405  2.33
# 434  292340        2        마이티 200커버드콜ATM레버리지   9470   2   215  2.32
# 92   292500        1              SMART KRX300  17610   2   400  2.32
# 108  337140        2              KODEX 코스피대형주  13360   2   300  2.30
# 172  315960        2          KBSTAR 대형고배당10TR  14740   2   330  2.29
# 61   144600        5              KODEX 은선물(H)   5400   2   120  2.27
# 242  168300        1                KTOP 코스피50  27130   2   600  2.26
# 36   315930        2          KODEX Top5PlusTR  16965   2   375  2.26
# 309  333970        2          ARIRANG KS밸류가중TR  13835   2   305  2.25
# 30   332940        1      HANARO MSCI Korea TR  15430   2   340  2.25
# 10   233740        1         KODEX 코스닥150 레버리지  15850   2   345  2.23
# 5    278540        1       KODEX MSCI Korea TR  12285   2   265  2.20
# 60   233160        1         TIGER 코스닥150 레버리지  16830   2   360  2.19
# 66   290130        2          KBSTAR ESG사회책임투자  12190   2   260  2.18
# 235  291630        3        KOSEF 코스닥150선물레버리지   6795   2   145  2.18
# 241  153270        1              KOSEF 코스피100  29010   2   610  2.15
# 78   156080        1          KODEX MSCI Korea  18260   2   385  2.15
# 146  266370        2                  KODEX IT  18820   2   385  2.09
# 148  310960        1               TIGER 200TR  19805   2   405  2.09
# 333  138920        5              KODEX 콩선물(H)  10525   2   215  2.09
# 1    102110        1                 TIGER 200  37845   2   770  2.08
# 214  152280        1              KOSEF 200 선물  17025   2   345  2.07
# 11   148020        1                KBSTAR 200  37910   2   770  2.07
# 209  266160        2                KBSTAR 고배당  11095   2   225  2.07
# 251  138520        2            TIGER 삼성그룹펀더멘털  11655   2   235  2.06
# 57   332930        1              HANARO 200TR  44185   2   890  2.06
# 233  237350        1              KODEX 코스피100  29330   2   590  2.05
# 19   293180        1                HANARO 200  37885   2   760  2.05
# 114  091230        2                 TIGER 반도체  32390   2   650  2.05
# 86   091160        2                 KODEX 반도체  31590   2   635  2.05
# 165  108590        1                  TREX 200  38105   2   760  2.04
# 28   294400        1               KOSEF 200TR  44145   2   880  2.03
# 76   292190        1              KODEX KRX300  17670   2   350  2.02
#
#         일평균가  3개월수익율     거래량/일  거래금액/일,백만  marketSum
# 101      0.0    35.5    794960       2077        590
# 120  23701.0    56.2      6974        162        437
# 266  17108.0    53.4       337          5        120
# 67       0.0    12.3   1224208       2668       1156
# 244  39223.0    56.3      7347        285        137
# 294   8556.0    55.6    351687       2971        102
# 139  19793.0    55.8    135153       2647        335
# 167  20515.0    56.2    761586      15325        265
# 171  19565.0    55.5     21257        407        253
# 23       0.0    18.4   2063190      15006       4488
# 205  17324.0    52.8     28499        487        172
# 74   16328.0    55.4   2870708      46039       1020
# 7    21830.0    54.8  61296374    1305633      14090
# 232      0.0    21.5     26152        193        148
# 383  11528.0    27.1      1334         15         65
# 4    15440.0    26.9    260100       3982      16531
# 217  17490.0    25.3      6314        110        157
# 191  17761.0    24.3        32          0        195
# 434   9471.0    25.8        21          0         47
# 92   17634.0    25.0     13857        241        652
# 108  13367.0    25.4      1865         24        521
# 172  14773.0    28.6      7478        109        251
# 61       0.0    16.0    492669       2655       1345
# 242  27126.0    25.5       199          5        138
# 36   16981.0    24.2     16206        272       3122
# 309  13838.0    26.7     15684        215         97
# 30   15434.0    27.0       441          6       3564
# 10   15972.0    38.5  37120544     586102      11777
# 5    12296.0    27.3    715949       8701      16044
# 60   16942.0    38.3   1121297      18853       1388
# 66   12198.0    25.2    782598       9472       1164
# 235   6826.0    41.1      9382         63        143
# 241  29022.0    25.0       227          6        139
# 78   18304.0    26.6      1018         18        913
# 146  18868.0    27.2    109504       2047        320
# 148  19854.0    25.7     16075        314        317
# 333      0.0    24.7     12908        135         84
# 1    37943.0    25.6   1315297      49471      26813
# 214  17059.0    25.3       264          4        158
# 11   38003.0    25.6    333958      12565      11411
# 209  11143.0    23.9    123741       1366        166
# 251  11658.0    29.2     10649        123        131
# 57   44299.0    25.5     19696        865       1524
# 233  29454.0    24.6      3590        104        147
# 19   37973.0    25.6     78039       2944       5493
# 114  32408.0    21.3     76771       2469        466
# 86   31634.0    21.2    184735       5812        742
# 165  38188.0    25.3        50          1        267
# 28   44255.0    25.6      3590        157       3863
# 76   17674.0    25.2     79790       1398        990
