# %%
from bs4 import BeautifulSoup
import requests
url = 'http://naver.com'
html = requests.get(url).text
soup = BeautifulSoup(html, 'html.parser')
soup.find('div',{'class' : 'sc_newscast'}).find_all('a',{'class': 'issue'})
# Out:
# [<a class="issue" data-clk="quickarticle" href="http://news.naver.com/main/list.nhn?mode=LPOD&amp;mid=sec&amp;sid1=001&amp;sid2=140&amp;oid=001&amp;isYeonhapFlash=Y&amp;aid=0012486173">신규확진 614명, 닷새 연속 600명대…주말에도 확산세 지속(종합)</a>,
#  <a class="issue" data-clk="quickarticle" href="http://news.naver.com/main/list.nhn?mode=LPOD&amp;mid=sec&amp;sid1=001&amp;sid2=140&amp;oid=001&amp;isYeonhapFlash=Y&amp;aid=0012486425">양현종, 마이너리그서 4⅔이닝 1실점…솔로포 맞아</a>,
#  <a class="issue" data-clk="quickarticle" href="http://news.naver.com/main/list.nhn?mode=LPOD&amp;mid=sec&amp;sid1=001&amp;sid2=140&amp;oid=001&amp;isYeonhapFlash=Y&amp;aid=0012486422">영, 하루 확진 2월초 이후 최다…런던에선 반봉쇄 시위(종합)</a>,
#  <a class="issue" data-clk="quickarticle" href="http://news.naver.com/main/list.nhn?mode=LPOD&amp;mid=sec&amp;sid1=001&amp;sid2=140&amp;oid=001&amp;isYeonhapFlash=Y&amp;aid=0012486379">성남 서현고 김휘성군 실종 엿새째…경찰, 수색 범위 확대</a>,
# ...

# %%
"http://news.naver.com/main/list.nhn?mode=LPOD&amp;mid=sec&amp;sid1=001&amp;sid2=140&amp;oid=001&amp;isYeonhapFlash=Y&amp;aid=0012115146"
# Out:
# 'http://news.naver.com/main/list.nhn?mode=LPOD&amp;mid=sec&amp;sid1=001&amp;sid2=140&amp;oid=001&amp;isYeonhapFlash=Y&amp;aid=0012115146'

# %%
soup.find_all('div')
# Out:
# [<div id="u_skip"> <a href="#newsstand"><span>뉴스스탠드 바로가기</span></a> <a href="#themecast"><span>주제별캐스트 바로가기</span></a> <a href="#timesquare"><span>타임스퀘어 바로가기</span></a> <a href="#shopcast"><span>쇼핑캐스트 바로가기</span></a> <a href="#account"><span>로그인 바로가기</span></a> </div>,
# ...

# %%
print(soup.find_all('div'))
# Out:
# [<div id="u_skip"> <a href="#newsstand"><span>뉴스스탠드 바로가기</span></a> <a href="#themecast"><span>주제별캐스트 바로가기</span></a> <a href="#timesquare"><span>타임스퀘어 바로가기</span></a> <a href="#shopcast"><span>쇼핑캐스트 바로가기</span></a> <a href="#account"><span>로그인 바로가기</span></a> </div>, <div id="wrap"> <style type="text/css">._1syGnXOL{padding-right:18px;font-size:14px;line-height:0;letter-spacing:-.25px;color:#000}._1syGnXOL span,._1syGnXOL strong{line-height:49px}._1syGnXOL:before{display:inline-block;content:"";vertical-align:top;background-image:url(https://static-whale.pstatic.net/main/sprite-20201210@2x.png);background-repeat:no-repeat;background-size:114px 107px;width:18px;height:18px;margin:16px 8px 0 0;background-position:0 -89px}[data-useragent*="MSIE 8"] ._1syGnXOL:before{background-image:url(https://static-whale.pstatic.net/main/sprite-20201210.png)}._1syGnXOL._3dsvmZg2:before{background-position:-68px -63px}._1syGnXOL._1NBFx1WK:before{width:20px;height:20px;margin:15px 8px 0 0;background-p
# ...

# %%
# //*[@id="themecast"]/div[2]/div[2]/div/ul/li[1]/a[2]/p/text()

# %%
for i in range(naver_main):
    topic = soup.find_all('ul',{'class' : 'list_theme'})[i].find_all('li',{'class' : 'theme_item'})

    for idx, j in enumerate(topic):
        title = print(topic[idx].select('strong.title.elss')[0].text)
# Out:
# 오리지널보다 더 사랑받는 후속 과자들
# 만두의 신세계! 평범함을 벗어던진 만두 3종
# 나만의 레시피 선보이고, 창작 지원 포인트도 받고!
# 특이점이 온 요즘 라면, 2020 F/W 신상 11종
# 화끈하고 맛있는 매운 볶음면 추천 BEST 7
# 한국사람 입맛 저격! 전통주와 한식 페어링
# 삼양맛샵에서 온라인 쇼핑하고 2021년 캘린더 받자!
# 풀무원X듀자매, 쇼핑라이브 소문내기
# 햄버거를 가장 맛있게 먹는 5가지 방법
# 더 이상 서민음식이 아닌 메뉴 9가지
# 달콤한 시럽 한 스푼으로 집콕 홈 카페
# 나만의 레시피 선보이고, 창작 지원 포인트도 받고!
# 삼양식품X멕시카나 콜라보 신제품!
# 추운 겨울 따끈하게! 그때 그 추억 샘표국시 체험단 모집
# 신상 털이범 에디터의 '핫한 맥주' 시음기
# 겨울과 찰떡궁합, 뜨끈한 국물의 즉석 어묵탕
# '꾸지뽕'이란 신비한 열매를 아시나요?
# 막걸리 VS 맥주, 김치에 가장 어울리는 술은?
# 케이크 틀 없이 밥솥으로 만드는 간단 케이크
# 아이들과 크리스마스 기분 내며 만들어 보세요
# 버터의 왕, '기버터'의 모든 것
# 창의적인 아이디어의 크리스마스 디저트
# 소복소복 눈이 쌓인 것 같은 아이싱 쿠키

# %%
topic = soup.find_all('ul',{'class' : 'list_theme'})[i].find_all('li',{'class' : 'theme_item'})
topic[1]
# Out:
# <li class="theme_item" data-da-position="true" data-gdid="CAS_b501da35-48e5-11eb-ad1e-c348954ae07c">
# <a class="theme_thumb" data-clk="tcc_fod.list1cont2" href="https://post.naver.com/viewer/postView.nhn?volumeNo=30276436&amp;memberNo=47856344" target="_blank">
# <img alt="만두의 신세계! 평범함을 벗어던진 만두 3종" data-src="https://s.pstatic.net/dthumb.phinf/?src=%22https%3A%2F%2Fs.pstatic.net%2Fstatic%2Fwww%2Fmobile%2Fedit%2F2020%2F1229%2Fupload_25162351052570478gMxui.JPEG%22&amp;type=nf340_228" height="114" src="https://s.pstatic.net/dthumb.phinf/?src=%22https%3A%2F%2Fs.pstatic.net%2Fstatic%2Fwww%2Fmobile%2Fedit%2F2020%2F1229%2Fupload_25162351052570478gMxui.JPEG%22&amp;type=nf340_228" width="170"/>
# <span class="thumb_bd"></span>
# </a>
# <a class="theme_info" data-clk="tcc_fod.list1cont2" href="https://post.naver.com/viewer/postView.nhn?volumeNo=30276436&amp;memberNo=47856344" target="_blank">
# <em class="theme_category"> 푸드</em>
# <strong class="title elss">만두의 신세계! 평범함을 벗어던진 만두 3종</strong>
# ...

# %%
topic[1].select('strong.title.elss')[0].text
# Out:
# '만두의 신세계! 평범함을 벗어던진 만두 3종'

# %%
topic[1].select('p.desc')[0].text
# Out:
# '개성 넘치는 만두들의 행진(※개성만두 아님) 재택근무를 시작한 지 한 달이 다 되어가는 에디터. 마치 15년간 군만두만 먹으며 갇혀있던, 영화 <올드보이>의 주인공처럼 문밖에서 놓인 배달 음식만을 가져오는 게 일상이 되었다. 그래서 준비한 만두 리뷰! 네? 얘기가 왜 그렇게 되는 거죠? 하지만 평범한 만두만 먹으면 금발 물리게 된다. 그래서 조금'

# %%
topic[1].select('a.theme_thumb')[0]['href']
# Out:
# 'https://post.naver.com/viewer/postView.nhn?volumeNo=30276436&memberNo=47856344'

# %%
from bs4 import BeautifulSoup
import requests
issue_url = "https://news.naver.com/main/list.nhn?mode=LPOD&amp;mid=sec&amp;sid1=001&amp;sid2=140&amp;isYeonhapFlash=Y&amp;aid=0012115146"
html = requests.get(issue_url)
soup = BeautifulSoup(html, 'html.parser')
# Out:
# ---------------------------------------------------------------------------
# RemoteDisconnected                        Traceback (most recent call last)
# C:\Dev\Miniconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     669             # Make the request on the httplib connection object.
# --> 670             httplib_response = self._make_request(
#     671                 conn,
#
# C:\Dev\Miniconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     425                     # Otherwise it looks like a bug in the code.
# --> 426                     six.raise_from(e, None)
#     427         except (SocketTimeout, BaseSSLError, SocketError) as e:
#
# C:\Dev\Miniconda3\lib\site-packages\urllib3\packages\six.py in raise_from(value, from_value)
#
# ...

# %%
soup

# %%
from bs4 import BeautifulSoup
import pandas as pd
import requests
url = 'https://finance.naver.com/item/coinfo.nhn?code=068270&target=finsum_more'
# html = requests.get(url)
# soup = BeautifulSoup(html.content, 'html.parser')
dfs = pd.read_html(url, encoding ='euc-kr')
dfs
# Out:
# [                      0                                            1  \
#  0  전일  329,000  329,000  고가  346,000346,000  (상한가  427,500427,500  )
#  1    시가  327,500327,500         저가  314,000314,000  (하한가  230,500  )
#
#                              2
#  0   거래량  2,419,088  2,419,088
#  1  거래대금  806,466  806,466  백만  ,
#            0               1
#  0      시가총액  42조  3,893  억원
#  1    시가총액순위          코스피 9위
#  2     상장주식수       134997805
#  3  액면가l매매단위   1,000원  l  1주,
#               0          1
#  0  외국인한도주식수(A)  134997805
#  1  외국인보유주식수(B)   27483966
#  2  외국인소진율(B/A)     20.36%,
#             0                    1
#  0  투자의견l목표주가   3.92매수  l  368,773
#  1   52주최고l최저  396,240  l  136,008,
#                     0                  1
#  0   PERlEPS(2020.09)  84.86배  l  3,700원
#  1          추정PERlEPS  73.00배  l  4,325원
#  2  PBRlBPS (2020.09)     ∞배  l  23,717원
#  3              배당수익률                NaN,
#            0        1
#  0  동일업종 PER  103.16배
#  1  동일업종 등락률   -3.55%,
# ...

# %%
현보유고_원 = [19190404,26705838]
현보유고_달러 = [19486]
미국주식_달러 = [2200*29.17,300*34.52,170*57.58,5*547.53,30*82.14]

전세보증금 = [50000000]
대출 = [66500000]

# %%
round(sum(현보유고_원 + 대출 + 전세보증금+ 1100 * (현보유고_달러+미국주식_달러)),0)
# Out:
# 282303337.0
